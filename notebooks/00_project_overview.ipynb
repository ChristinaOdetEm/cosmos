# %% [markdown]
# # Project Overview
#
# This notebook orients the analysis workflow. It is intentionally light on computation and heavy on process clarity.
#
# ## Foundation rules
# - Work from processed datasets when possible.
# - Keep raw files immutable.
# - Save figures to `outputs/figures/`.
# - Document durable transformations in code, not only in notebook cells.
# - Do not search for anomalies yet.

# %%
from pathlib import Path

import pandas as pd

from jwst_galaxy_analysis.config import get_paths

paths = get_paths()
paths

# %%
processed_files = sorted(paths.data_processed.glob('*.parquet'))
pd.DataFrame({'processed_dataset': [p.name for p in processed_files]})
